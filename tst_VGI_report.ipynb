# %% [markdown]
# # Geotagged Twitter data in Porto Alegre
#
# ##### this notebook presents a quick spatio-temporal analysis of geotagged tweets in Porto Alegre-BR and Rosario-AR
#
# ##### The script used to collect the tweets (clisap_tst.py) and the rasvested data are also available in this repository
#
# author: Joao Meirelles

# %%
#import libraries
# %matplotlib inline

from IPython.display import Image
import pandas as pd 
import os
os.environ['PROJ_LIB'] = '/home/jm/anaconda3/share/proj'
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
import warnings
import folium
warnings.filterwarnings('ignore')

# %% [markdown]
# ## PORTO ALEGRE - BR
#
# ##### Geotagged teets were collected between 18:00h of the 07/11/2018 and 06:00h of the 09/11/2018 (local time)
# there was a connection problem between 4am and 6am and no tweets were collected during this period
#
# ##### The are for which tweets were collect is presented in the bellow image

# %%
Image("area_POA.png",width=500)

# %% [markdown]
# ### Spatio-temporal analysis of twitter activity in POA

# %%
#read data

df = pd.read_csv("poa_tst_plot.csv") 

print(len(df.index))
df = df.drop_duplicates() #drop duplicates and check if there were any
print(len(df.index))

df['date_time'] =  pd.to_datetime(df['date_time'], format='%Y-%m-%d %H:%M:%S') #format datatype
df.dtypes

df.set_index('date_time', drop=False, inplace=True) #set datetime as index
df  = df.loc['2018-11-07 18:00:00':] # exclude incomplete initial hours


df.head()
# Out:
# 1782
# 1759
#                             id lang  \
# date_time
# 2018-11-07 18:00:31  191318673   pt
# 2018-11-07 18:00:58  592035990   pt
# 2018-11-07 18:02:19   54346243   pt
# 2018-11-07 18:03:00   28402552   pt
# 2018-11-07 18:03:53   18325569   it
#
#                                                                   text  \
# date_time
# 2018-11-07 18:00:31  'evangélica' e 'reajuste' é tendência em #Port...
# 2018-11-07 18:00:58  com nego kauê (@ Arte Tattoo in São Leopoldo, ...
# 2018-11-07 18:02:19  Sempre sonhei estar exatamente ali... atrás do...
# 2018-11-07 18:03:00  Contraste das cores. em Cais Mauá https://t.co...
# 2018-11-07 18:03:53  I'm at Confraria Do Pilates in Porto Alegre, R...
#
#                               date_time        lat       long
# date_time
# 2018-11-07 18:00:31 2018-11-07 18:00:31 -30.027700 -51.228700
# 2018-11-07 18:00:58 2018-11-07 18:00:58 -29.744320 -51.159430
# 2018-11-07 18:02:19 2018-11-07 18:02:19 -30.030100 -51.232323
# 2018-11-07 18:03:00 2018-11-07 18:03:00 -30.031513 -51.240300
# 2018-11-07 18:03:53 2018-11-07 18:03:53 -30.049132 -51.207291

# %% [markdown]
# there where aprox 1300 tweets within those 24h in the region

# %% [markdown]
# #### Temporal dynamic
# The volume of geotagget tweets collected in the region is small. 1/min in the peak hours.
#
# Once were are unlilekly to be reaching the limit of the API (1% of global tweets volume), it can be inferred that the region is not very active in geotagged tweets. I can also be the case that we are beein limited by the API, would need to further investigate it.

# %%
houraggregation = df['id'].groupby(pd.TimeGrouper(freq='60Min')).count()
#houraggregation.head()
#houraggregation.plot(kind='bar', color='k')
houraggregation.plot(color='k');

# %% [markdown]
# #### Spatial Distribution
#
# It's possible to observe a few tweets outside of urban regions, but not enough to infere housing.

# %%
# basemap
# Other tiles:
# OpenStreetMap, Stamen Terrain, Stamen Toner, Mapbox Bright, and Mapbox Control Room
m = folium.Map(location=[-29.95, -51], tiles="Stamen Terrain", zoom_start=10)

# add tweets as points
for i in range(0,len(df)):
   folium.Circle(
      location=[df.iloc[i]['lat'], df.iloc[i]['long']],
      #popup=data.iloc[i]['name'],
      radius=50,
      color='crimson',
      fill=True,
      fill_color='crimson',
       opacity=1
   ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### night tweets
#
# map of tweets between 23:00 and 05:00
#
# likely to be home locations

# %%
#subset night tweets
df_night = df.between_time('23:00','05:00')

# %%
m = folium.Map(location=[-29.95, -51], tiles="Stamen Terrain", zoom_start=10)

for i in range(0,len(df_night)):
   folium.Circle(
      location=[df_night.iloc[i]['lat'], df_night.iloc[i]['long']],
      #popup=data.iloc[i]['name'],
      radius=50,
      color='blue',
      fill=True,
      fill_color='blue',
       opacity=1
   ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## ROSARIO - AR
#
# ##### Geotagged teets were collected between 00:00h of the 12/11/2018 and 08:00h of the 15/11/2018 (local time)
# there was a connection problem between 4am and 6am and no tweets were collected during this period
#
# ##### The are for which tweets were collect is presented in the bellow image

# %%
Image("area_ROS.png",width=500)

# %% [markdown]
# ### Spatio-temporal analysis of twitter activity in ROS

# %%
#read data

df = pd.read_csv("./ros_tst_plot.csv") 

print(len(df.index))
df = df.drop_duplicates() #drop duplicates and check if there were any
print(len(df.index))

df['date_time'] =  pd.to_datetime(df['date_time'], format='%Y-%m-%d %H:%M:%S') #format datatype
df.dtypes

df.set_index('date_time', drop=False, inplace=True) #set datetime as index
df  = df.loc['2018-11-11 00:00:00':'2018-11-15 04:00:00'] # exclude incomplete initial hours

print(len(df.index))
df.head()
# Out:
# 977
# 977
# 904
#                                id lang  \
# date_time
# 2018-11-12 00:03:06  7.753543e+17   es
# 2018-11-12 00:06:10  7.550631e+17   es
# 2018-11-12 00:20:56  1.994644e+08   es
# 2018-11-12 00:25:06  2.834269e+09   es
# 2018-11-12 00:28:15  7.667810e+08   es
#
#                                                                   text  \
# date_time
# 2018-11-12 00:03:06  Que tengas un excelente arranque de semana!!!\...
# 2018-11-12 00:06:10  D o m i n g o 💜🍃☁️ en Mocoretá, Corrientes, Ar...
# 2018-11-12 00:20:56  'reinicia' es ahora una tendencia en #Rosario\...
# 2018-11-12 00:25:06  ≈12,5 km (intensidad 8/10, área 8/10)\nhttps:/...
# 2018-11-12 00:28:15  SIEMPRE ESTOY.....DISPUESTA....PARA AYUDAR A Q...
#
#                               date_time       lat       long
# date_time
# 2018-11-12 00:03:06 2018-11-12 00:03:06 -32.95110 -60.666400
# 2018-11-12 00:06:10 2018-11-12 00:06:10 -30.61981 -57.978180
# 2018-11-12 00:20:56 2018-11-12 00:20:56 -32.94680 -60.639300
# 2018-11-12 00:25:06 2018-11-12 00:25:06 -32.95233 -60.652271
# 2018-11-12 00:28:15 2018-11-12 00:28:15 -32.46330 -58.478090

# %% [markdown]
# there where aprox 900 tweets within those 72h in the region

# %% [markdown]
# #### Temporal dynamic
# The volume of geotagget tweets collected in the region is small. 0.5/min in the peak hours.
#
# Once were are unlilekly to be reaching the limit of the API (1% of global tweets volume), it can be inferred that the region is not very active in geotagged tweets. I can also be the case that we are beein limited by the API, would need to further investigate it.

# %%
houraggregation = df['id'].groupby(pd.TimeGrouper(freq='60Min')).count()
#houraggregation.head()
#houraggregation.plot(kind='bar', color='k')
houraggregation.plot(color='k');

# %% [markdown]
# #### Spatial Distribution
#
# It's possible to observe a few tweets outside of urban regions, but not enough to infere housing.

# %%
# basemap
# Other tiles:
# OpenStreetMap, Stamen Terrain, Stamen Toner, Mapbox Bright, and Mapbox Control Room
m = folium.Map(location=[-33, -60.5], tiles="Stamen Terrain", zoom_start=10)

# add tweets as points
for i in range(0,len(df)):
   folium.Circle(
      location=[df.iloc[i]['lat'], df.iloc[i]['long']],
      #popup=data.iloc[i]['name'],
      radius=50,
      color='crimson',
      fill=True,
      fill_color='crimson',
       opacity=1
   ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### night tweets
#
# map of tweets between 23:00 and 05:00
#
# likely to be home locations

# %%
#subset night tweets
df_night = df.between_time('23:00','05:00')

# %%
m = folium.Map(location=[-33, -60.5], tiles="Stamen Terrain", zoom_start=10)

for i in range(0,len(df_night)):
   folium.Circle(
      location=[df_night.iloc[i]['lat'], df_night.iloc[i]['long']],
      #popup=data.iloc[i]['name'],
      radius=50,
      color='blue',
      fill=True,
      fill_color='blue',
       opacity=1
   ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
